# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_Test_split
from sklearn.metrics import accuracy_score, precision_score
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.linear_model import LogisticRegresssion
#       3 from sklearn.model_selection import train_Test_split
#       4 from sklearn.metrics import accuracy_score, precision_score
#
# ImportError: cannot import name 'LogisticRegresssion' from 'sklearn.linear_model' (/Users/ravihw18/ML-Algorithms/.venv/lib/python3.14/site-packages/sklearn/linear_model/__init__.py)
